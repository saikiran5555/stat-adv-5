# %% [markdown]
# To calculate the 99% confidence interval for the true proportion of people in the population who prefer Coke, you can use the formula for the confidence interval of a proportion. The formula is:
#
# CI
# =
# �
# ^
# ±
# �
# ×
# �
# ^
# (
# 1
# −
# �
# ^
# )
# �
# CI=
# p
# ^
# ​
#  ±Z×
# n
# p
# ^
# ​
#  (1−
# p
# ^
# ​
#  )
# ​
#
# ​
#
#
# Where:
#
# �
# ^
# p
# ^
# ​
#   is the sample proportion.
# �
# Z is the Z-value from the standard normal distribution for the desired confidence level (for 99%,
# �
# Z is approximately 2.576).
# �
# n is the sample size.
# Given:
#
# Sample Proportion (
# �
# ^
# p
# ^
# ​
#  ): 520 out of 1000 preferred Coke, so
# �
# ^
# =
# 520
# 1000
# =
# 0.52
# p
# ^
# ​
#  =
# 1000
# 520
# ​
#  =0.52.
# Sample Size (n): 1000
# Confidence Level: 99% (which gives us a Z-value of about 2.576).
# Step 1: Calculate the Standard Error (SE)
# �
# �
# =
# �
# ^
# (
# 1
# −
# �
# ^
# )
# �
# SE=
# n
# p
# ^
# ​
#  (1−
# p
# ^
# ​
#  )
# ​
#
# ​
#
# �
# �
# =
# 0.52
# (
# 1
# −
# 0.52
# )
# 1000
# SE=
# 1000
# 0.52(1−0.52)
# ​
#
# ​
#
# �
# �
# =
# 0.52
# ×
# 0.48
# 1000
# SE=
# 1000
# 0.52×0.48
# ​
#
# ​
#
# �
# �
# =
# 0.2496
# ÷
# 1000
# SE=
# 0.2496÷1000
# ​
#
# �
# �
# =
# 0.0002496
# SE=
# 0.0002496
# ​
#
# �
# �
# ≈
# 0.0158
# SE≈0.0158
#
# Step 2: Calculate the Margin of Error
# Margin of Error
# =
# �
# ×
# �
# �
# Margin of Error=Z×SE
# Margin of Error
# =
# 2.576
# ×
# 0.0158
# Margin of Error=2.576×0.0158
# Margin of Error
# ≈
# 0.0407
# Margin of Error≈0.0407
#
# Step 3: Calculate the Confidence Interval
# CI
# =
# �
# ^
# ±
# Margin of Error
# CI=
# p
# ^
# ​
#  ±Margin of Error
# CI
# =
# 0.52
# ±
# 0.0407
# CI=0.52±0.0407
# CI
# =
# [
# 0.52
# −
# 0.0407
# ,
# 0.52
# +
# 0.0407
# ]
# CI=[0.52−0.0407,0.52+0.0407]
# CI
# =
# [
# 0.4793
# ,
# 0.5607
# ]
# CI=[0.4793,0.5607]
#
# Interpretation:
# The 99% confidence interval for the true proportion of people in the population who prefer Coke is from approximately 47.93% to 56.07%. This means we can be 99% confident that the actual proportion of people preferring Coke in the general population falls within this range
